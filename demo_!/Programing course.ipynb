# %% [markdown]
# # NUMBER GUESSING GAME LEVEL 1

# %%
print("""Instructions
Enter the range of numbers you want the target number to be between, and press New Target
Enter your guess
See if your guess is too high or too low
Change your guess
The app will tell you when you are right, and how many guesses you had
 """)
# Out:
# Instructions
# Enter the range of numbers you want the target number to be between, and press New Target
# Enter your guess
# See if your guess is too high or too low
# Change your guess
# The app will tell you when you are right, and how many guesses you had

# %% [markdown]
# ## Print if the user guest number is right or not

# %%
secret_number = 56
user_id = int(input("enter your guess = ")
if secret_number == user_id:
    print("you guess is correct")
else:
    print("your guess is wrong")
# Out:
# enter your guess =  56
# you guess is correct

# %% [markdown]
# # NUMBER GUESSING GAME LEVEL 2

# %% [markdown]
# ## Guess the correct number with the maximum of seven tries using for loop

# %%
secret_number = 56

for i in range(0,7):
    user_id = int(input("enter your guess = "))
    if secret_number == user_id:
        print("you guess is correct")
        break
    else:
        print("your guess is wrong")
# Out:
# enter your guess =  56
# you guess is correct

# %% [markdown]
# # Guess the correct number with the maximum of seven tries using while loop

# %%
secret_number = 56

while True:
    user_id = int(input("enter your guess = "))
    if secret_number == user_id:
        print("you guess is correct")
        break
    else:
        print("your guess is wrong")
# Out:
# enter your guess =  56
# you guess is correct

# %% [markdown]
# # number guessing game level 3

# %% [markdown]
# ## giving multiple condition
#
# 1. user should enter the number between 1 to 100
# 2. if the user number greater than the secrete than the program should say your number is greater than the secret number
# 3. if the user number lesser than the secrete than the program should say your number is lesser than the secret number

# %%
print(" welcome to number guessing game")
print("Guess the number your Lucky!! hint: The number falls between 1 to 100")
secret_number = 65
for i in range(0,7):
    user_input = int(input("Enter your guess = "))
                     
    if user_input <1 or user_input >100:
        print("invalid number please enter the number between 1 to 100")

    elif user_input > secret_number:
        print("your number is higher")
    elif user_input < secret_number:
        print("your number is loweer")

    else:
        print("your guessed number is correct ")
        print(f"congratulation, You have guessed the number", {secret_number}, "in", {i}, "attempts")
        break
# Out:
#  welcome to number guessing game
# Guess the number your Lucky!! hint: The number falls between 1 to 100
# Enter your guess =  45
# your number is loweer
# Enter your guess =  12
# your number is loweer
# Enter your guess =  69
# your number is higher
# Enter your guess =  65
# your guessed number is correct
# congratulation, You have guessed the number {65} in {3} attempts

# %%
print("""Instructions
Enter the range of numbers you want the target number to be between, and press New Target
Enter your guess
See if your guess is too high or too low
Change your guess
The app will tell you when you are right, and how many guesses you had
 """)
print(" welcome to number guessing game")
print("Guess the number your Lucky!! hint: The number falls between 1 to 100")

secret_number = 25

for i in range(0,7):
    user_input = int(input("Guess The Number = "))

    if user_input < 1 or user_input > 100:
        print("you given inavlid number please the selecet the number between 1 to 10")

    elif user_input > secret_number:
        print("you number is too high")

    elif user_input < secret_number:
        print("your number is too low")

    else:
        print("your number is correct")
        print(f"you have got your number", {secret_number}, "in", {i}, "attempts") 
        break
# Out:
# Instructions
# Enter the range of numbers you want the target number to be between, and press New Target
# Enter your guess
# See if your guess is too high or too low
# Change your guess
# The app will tell you when you are right, and how many guesses you had
#
#  welcome to number guessing game
# Guess the number your Lucky!! hint: The number falls between 1 to 100
# Guess The Number =  42
# you number is too high
# Guess The Number =  45
# you number is too high
# Guess The Number =  25
# your number is correct
# you have got your number {25} in {2} attempts
# Guess The Number =  12
# your number is too low
# Guess The Number =  1
# your number is too low
# Guess The Number =  1
# your number is too low
# Guess The Number =  2
# your number is too low

# %%
print("""Instructions
Enter the range of numbers you want the target number to be between, and press New Target
Enter your guess
See if your guess is too high or too low
Change your guess
The app will tell you when you are right, and how many guesses you had
 """)
print(" welcome to number guessing game")
print("Guess the number your Lucky!! hint: The number falls between 1 to 100")

secret_number = 25

while True:
    user_input = int(input("Guess The Number = "))

    if user_input < 1 or user_input > 100:
        print("you given inavlid number please the selecet the number between 1 to 10")

    elif user_input > secret_number:
        print("you number is too high")

    elif user_input < secret_number:
        print("your number is too low")

    else:
        print("your number is correct")
        #print(f"you have got your number", {secret_number}, "in", {i}, "attempts") 
        break
# Out:
# Instructions
# Enter the range of numbers you want the target number to be between, and press New Target
# Enter your guess
# See if your guess is too high or too low
# Change your guess
# The app will tell you when you are right, and how many guesses you had
#
#  welcome to number guessing game
# Guess the number your Lucky!! hint: The number falls between 1 to 100
# Guess The Number =  41
# you number is too high
# Guess The Number =  21
# your number is too low
# Guess The Number =  26
# you number is too high
# Guess The Number =  25
# your number is correct

# %% [markdown]
# ## leve 3

# %%
print("""Instructions
Enter the range of numbers you want the target number to be between, and press New Target
Enter your guess
See if your guess is too high or too low
Change your guess
The app will tell you when you are right, and how many guesses you had
 """)
print(" welcome to number guessing game")
print("Guess the number your Lucky!! hint: The number falls between 1 to 100")

secret_number = 25

for i in range(0,7):
    user_input = int(input("Guess The Number = "))

    if user_input < 1 or user_input > 100:
        print("you given inavlid number please the selecet the number between 1 to 10")

    elif user_input > secret_number:
        print("you number is too high")

    elif user_input < secret_number:
        print("your number is too low")

    else:
        print("your number is correct")
        break
    
if secret_number == user_input:
    print(f"you have got your number", {secret_number}, "in", {i}, "attempts") 
else:
    print("all your trials is exceeeded. Try again")
# Out:
# Instructions
# Enter the range of numbers you want the target number to be between, and press New Target
# Enter your guess
# See if your guess is too high or too low
# Change your guess
# The app will tell you when you are right, and how many guesses you had
#
#  welcome to number guessing game
# Guess the number your Lucky!! hint: The number falls between 1 to 100
# Guess The Number =  12
# your number is too low
# Guess The Number =  12
# your number is too low
# Guess The Number =  12
# your number is too low
# Guess The Number =  12
# your number is too low
# Guess The Number =  12
# your number is too low
# Guess The Number =  12
# your number is too low
# Guess The Number =  12
# your number is too low
# all your trials is exceeeded. Try again

# %% [markdown]
# # NUMBER GUESSING GAME LEVEL 5

# %% [markdown]
# ## it should be a random number not to be a fixed number

# %%
import random

# %%
random.randint(1,100)
# Out:
# 64

# %%
import random
print("""Instructions
Enter the range of numbers you want the target number to be between, and press New Target
Enter your guess
See if your guess is too high or too low
Change your guess
The app will tell you when you are right, and how many guesses you had
 """)
print(" welcome to number guessing game")
print("Guess the number your Lucky!! hint: The number falls between 1 to 100")

secret_number = random.randint(1,100)

for i in range(0,7):
    user_input = int(input("Guess The Number = "))

    if user_input < 1 or user_input > 100:
        print("you given inavlid number please the selecet the number between 1 to 10")

    elif user_input > secret_number:
        print("you number is too high")

    elif user_input < secret_number:
        print("your number is too low")

    else:
        print("your number is correct")
        break
    
if secret_number == user_input:
    print(f"you have got your number", secret_number, "in", i, "attempts") 
else:
    print("all your trials is exceeeded. Try again")
# Out:
# Instructions
# Enter the range of numbers you want the target number to be between, and press New Target
# Enter your guess
# See if your guess is too high or too low
# Change your guess
# The app will tell you when you are right, and how many guesses you had
#
#  welcome to number guessing game
# Guess the number your Lucky!! hint: The number falls between 1 to 100
# Guess The Number =  65
# you number is too high
# Guess The Number =  25
# your number is too low
# Guess The Number =  30
# you number is too high
# Guess The Number =  26
# your number is correct
# you have got your number 26 in 3 attempts

# %% [markdown]
# ## level 6 how to handle invalid charcters

# %%
import random
print("""Instructions
Enter the range of numbers you want the target number to be between, and press New Target
Enter your guess
See if your guess is too high or too low
Change your guess
The app will tell you when you are right, and how many guesses you had
 """)
print(" welcome to number guessing game")
print("Guess the number your Lucky!! hint: The number falls between 1 to 100")

secret_number = random.randint(1,100)

for i in range(0,7):
    try:
        user_input = int(input("Guess The Number = "))
    
        if user_input < 1 or user_input > 100:
            print("you given inavlid number please the selecet the number between 1 to 10")
    
        elif user_input > secret_number:
            print("you number is too high")
    
        elif user_input < secret_number:
            print("your number is too low")
    
        else:
            print("your number is correct")
            break
    except ValueError:
        print("invalid characters not recogonized please enter the  numbers to play this game")
if secret_number == user_input:
    print(f"you have got your number", secret_number, "in", i, "attempts") 
else:
    print("all your trials is exceeeded. Try again")
# Out:
# Instructions
# Enter the range of numbers you want the target number to be between, and press New Target
# Enter your guess
# See if your guess is too high or too low
# Change your guess
# The app will tell you when you are right, and how many guesses you had
#
#  welcome to number guessing game
# Guess the number your Lucky!! hint: The number falls between 1 to 100
# Guess The Number =  25
# you number is too high
# Guess The Number =  ll
# invalid characters not recogonized please enter the  numbers to play this game
# Guess The Number =  52
# you number is too high
# Guess The Number =  12
# you number is too high
# Guess The Number =  6
# your number is too low
# Guess The Number =  9
# your number is too low
# Guess The Number =  11
# you number is too high
# all your trials is exceeeded. Try again

# %% [markdown]
# ## user defined functions level 7

# %% [markdown]
# #### take this program to run as a function when it is called

# %% [markdown]
# step 1: Define a function
# step 2 : call the functiong

# %%
def number_guessing_game():
    import random
    print("""Instructions
    Enter the range of numbers you want the target number to be between, and press New Target
    Enter your guess
    See if your guess is too high or too low
    Change your guess
    The app will tell you when you are right, and how many guesses you had
     """)
    print(" welcome to number guessing game")
    print("Guess the number your Lucky!! hint: The number falls between 1 to 100")
    
    secret_number = random.randint(1,100)
    
    for i in range(0,7):
        try:
            user_input = int(input("Guess The Number = "))
        
            if user_input < 1 or user_input > 100:
                print("you given inavlid number please the selecet the number between 1 to 10")
        
            elif user_input > secret_number:
                print("you number is too high")
        
            elif user_input < secret_number:
                print("your number is too low")
        
            else:
                print("your number is correct")
                break
        except ValueError:
            print("invalid characters not recogonized please enter the  numbers to play this game")
    if secret_number == user_input:
        print(f"you have got your number", secret_number, "in", i, "attempts") 
    else:
        print("all your trials is exceeeded. Try again")

# %%
number_guessing_game()
# Out:
# Instructions
#     Enter the range of numbers you want the target number to be between, and press New Target
#     Enter your guess
#     See if your guess is too high or too low
#     Change your guess
#     The app will tell you when you are right, and how many guesses you had
#
#  welcome to number guessing game
# Guess the number your Lucky!! hint: The number falls between 1 to 100
# Guess The Number =  56
# you number is too high
# Guess The Number =  40
# your number is too low
# Guess The Number =  48
# you number is too high
# Guess The Number =  45
# you number is too high
# Guess The Number =  44
# your number is correct
# you have got your number 44 in 4 attempts

# %%
import random

# %%
def number_game():
    
    import random
    
    secret_number = random.randint(1,100)
    
    for i in range(0,7):
        try:
            user_input = int(input("Enter you number = "))
        
            if user_input < 1 or user_input > 100:
                print("enter number between 1 to 100")
        
            elif user_input < secret_number:
                print("you are lesser")
                
            elif user_input > secret_number:
                print("you are higher")
            else:
                print("you are correct")
                break
        except ValueError:
            print("invalid characters please enter numbers")
    
    if secret_number == user_input:
        print(f"congratulationa you have got your", secret_number, "in", i, "attempts")
    else:
        print("you have lost your try please try again")

# %%
number_game()
# Out:
# Enter you number =  kk
# invalid characters please enter numbers
# Enter you number =  jnj
# invalid characters please enter numbers
# Enter you number =  nn
# invalid characters please enter numbers
# Enter you number =  dd
# invalid characters please enter numbers
# Enter you number =  11
# you are lesser
# Enter you number =  ff
# invalid characters please enter numbers
# Enter you number =  ff
# invalid characters please enter numbers
# you have lost your try please try again

# %% [markdown]
# ### will continue later
