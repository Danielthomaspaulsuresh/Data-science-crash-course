# %% [markdown]
# ## Why Python built-in Data structures
#
# *To collect Multiple data in a structure
#
# ### 4 data structures in python
# * lists
# * tuples
# * Dictionaries = Key & value
# * sets

# %% [markdown]
# # 1. list
# #### Properties of list
# * 1Dimensional
# * list is heterogenous data structure allows str,float,int
# * List accepts duplicate values
# * Index number always starts from 0 (postive) and (negative starts from -1) and slicing
# * mutable that means we can change the value whenever we want in the future

# %%
empty_cart = []

# %%
empty_cart
# Out:
# []

# %%
type(empty_cart)
# Out:
# list

# %%
items_to_buy = ["apple","orange","grapes","bannana","apple",6.76,8,9]

# %%
items_to_buy
# Out:
# ['apple', 'orange', 'grapes', 'bannana', 'apple', 6.76, 8, 9]

# %%
 len(items_to_buy)
# Out:
# 8

# %%
items_to_buy[0] #indexing
# Out:
# 'apple'

# %%
items_to_buy[3]
# Out:
# 'bannana'

# %%
items_to_buy[-6]
# Out:
# 'grapes'

# %%
items_to_buy[0:3]
# Out:
# ['apple', 'orange', 'grapes']

# %%
items_to_buy[2:4]
# Out:
# ['grapes', 'bannana']

# %%
items_to_buy[-7:-4]
# Out:
# ['orange', 'grapes', 'bannana']

# %%
items_to_buy = ["apple","orange","grapes","bannana","apple",6.76,8,9]

# %%
items_to_buy[1] = "watermelon" # mutable

# %%
items_to_buy
# Out:
# ['apple', 'watermelon', 'grapes', 'bannana', 'apple', 6.76, 8, 9]

# %% [markdown]
# # 2. SETS
# * 1D
# * it is heterogenous data structure it allows float,str,int
# * it wont allow duplicate values
# * Indexing and slicing is not possible
# * its mutable by using the add() and discard() function

# %%
empty_cart2 = set()

# %%
empty_cart2
# Out:
# set()

# %%
type(empty_cart2)
# Out:
# set

# %%
items_to_buy2 = {"apple","orange","grapes","bannana","apple",6.76,8,9}

# %%
items_to_buy2
# Out:
# {6.76, 8, 9, 'apple', 'bannana', 'grapes', 'orange'}

# %%
type(items_to_buy2)
# Out:
# set

# %%
items_to_buy2[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 items_to_buy2[1]
#
# TypeError: 'set' object is not subscriptable

# %%
items_to_buy2
# Out:
# {6.76, 8, 9, 'apple', 'bannana', 'grapes', 'orange'}

# %%
items_to_buy2.add("pomogranate")
items_to_buy2
# Out:
# {6.76, 8, 9, 'apple', 'bannana', 'grapes', 'orange', 'pomogranate'}

# %%
items_to_buy2.discard("apple")
items_to_buy2
# Out:
# {6.76, 8, 9, 'bannana', 'grapes', 'orange', 'pomogranate'}

# %% [markdown]
# ## 3.Tuple
# * 1D
# * allow duplicate vslue
# * Its hetrogenous allows str,float,int
# * you can do indexing in postive and negative way
# * but you cant change anything inside tuple bybusing functions or indexing its immutable

# %%
empty_cart3 = ()

# %%
empty_cart3
# Out:
# ()

# %%
type(empty_cart3)
# Out:
# tuple

# %%
items_to_buy3 = ("apple","orange","grapes","bannana","apple",6.76,8,9)
items_to_buy3
# Out:
# ('apple', 'orange', 'grapes', 'bannana', 'apple', 6.76, 8, 9)

# %%
type(empty_cart3)
# Out:
# tuple

# %%
items_to_buy3[0]
# Out:
# 'apple'

# %%
items_to_buy3[1:5]
# Out:
# ('orange', 'grapes', 'bannana', 'apple')

# %%
items_to_buy3[1] = "watermelon"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 items_to_buy3[1] = "watermelon"
#
# TypeError: 'tuple' object does not support item assignment

# %%
items_to_buy3.count("apple")
# Out:
# 2

# %%
items_to_buy3.index("apple")
# Out:
# 0

# %% [markdown]
# ## 4 dictionaries
# * it is a key:value pair
# * 2dimensional
# * its a heterogenous accepts float,int,str
# * its mutable you can change value inside using function
# * indexing and slicing is not posiible
# * dont create duplicate key but you create duplicate values key is important

# %%
empty_cart4 = {}
empty_cart4
# Out:
# {}

# %%
type(empty_cart4)
# Out:
# dict

# %%
student_marks = {33,66,77}
type(student_marks)
# Out:
# set

# %%
student_mark = {"maths":89,
"english":98,
"science":88}

# %%
type(student_mark)
# Out:
# dict

# %%
items_to_buy4 = {"pottata":5,
"tomata":4,
"apple":6}

# %%
items_to_buy4
# Out:
# {'pottata': 5, 'tomata': 4, 'apple': 6}

# %%
type(items_to_buy4)
# Out:
# dict

# %%
items_to_buy4[2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 items_to_buy4[2]
#
# KeyError: 2

# %%
items_to_buy4.clear()

# %%
items_to_buy4
# Out:
# {}

# %%
c

# %%
items_to_buy4.keys()
# Out:
# dict_keys(['pottata', 'tomata', 'apple'])

# %%
items_to_buy4.values()
# Out:
# dict_values([5, 4, 6])

# %%
items_to_buy4 = {"pottata":5,
"tomata":4,
"apple":6}
items_to_buy4
# Out:
# {'pottata': 5, 'tomata': 4, 'apple': 6}

# %%
import pandas as pd

# %%
pd.DataFrame(data = items_to_buy4)

# %%
student_marks1 = {"name":["kiruthic","hari","ragul"],"maths":[67,88,88],
                  "science":[77,66,88],"english":[88,44,77]}

# %%
student_marks1
# Out:
# {'name': ['kiruthic', 'hari', 'ragul'],
#  'maths': [67, 88, 88],
#  'science': [77, 66, 88],
#  'english': [88, 44, 77]}

# %%
pd.DataFrame(data = student_marks1)
# Out:
#        name  maths  science  english
# 0  kiruthic     67       77       88
# 1      hari     88       66       44
# 2     ragul     88       88       77

# %%
# Out:
#   Cell In[88], line 1
#     git init
#         ^
# SyntaxError: invalid syntax
